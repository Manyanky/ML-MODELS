# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

from sklearn import model_selection

# Loading the datasest Sets
Training_data = pd.read_csv('Train_maskedv2.csv')
sampleSubmission = pd.read_csv('samplesubmissionv2.csv')
Testing_data = pd.read_csv('Test_maskedv2.csv')
full_data = [Training_data, Testing_data]

Training_data.head(3)
# Out:
#       ward  total_households  total_individuals  target_pct_vunerable  \
# 0  9D9BEUB       13569.97801        39024.03083              1.739801
# 1  RERH3XM       13593.88256        32879.94646              1.993381
# 2  GJWA3BO        2698.30050         8261.71093              0.038340
#
#       dw_00     dw_01     dw_02     dw_03     dw_04     dw_05  ...    lan_11  \
# 0  0.354806  0.004781  0.170498  0.007861  0.006796  0.023082  ...  0.001723
# 1  0.262140  0.002066  0.077669  0.000597  0.000977  0.003759  ...  0.041982
# 2  0.728101  0.002292  0.051663  0.008209  0.001444  0.005089  ...  0.014786
#
#      lan_12  lan_13    lan_14     pg_00     pg_01     pg_02     pg_03  \
# 0  0.027796       0  0.026727  0.524666  0.041460  0.394550  0.029031
# 1  0.021312       0  0.015754  0.993900  0.001829  0.000854  0.000586
# 2  0.005827       0  0.049384  0.990007  0.003582  0.002546  0.003201
#
#       pg_04    lgt_00
# 0  0.010292  0.599259
# 1  0.002832  0.699136
# 2  0.000663  0.972315
#
# [3 rows x 50 columns]

# %%
# Observe the Correlation to the Target Variable

cst =Training_data.corr()['target_pct_vunerable'].copy()
cst = cst.drop('target_pct_vunerable')
cst.sort_values(inplace=True)
cst.plot(kind='bar', alpha=0.6)

# %%
Testing_data
# Out:
#       total_households  total_individuals     dw_00     dw_01     dw_02  \
# 0           2514.04172         8037.06199  0.671962  0.061074  0.101516
# 1           1829.71944         7494.86917  0.542857  0.390850  0.039623
# 2           1721.99009         5847.43254  0.968071  0.003525  0.001431
# 3          12388.02257        52211.66859  0.397274  0.004734  0.001068
# 4           1754.25716         4266.57609  0.815197  0.016697  0.078571
# ...                ...                ...       ...       ...       ...
# 1097        1871.18898         6946.20305  0.226464  0.629322  0.039062
# 1098        2164.66856         5974.39531  0.738136  0.003566  0.005022
# 1099        3822.71308        13000.22241  0.927417  0.000890  0.012602
# 1100        2075.42181        10280.57452  0.410837  0.002468  0.011511
# 1101        1917.11141         6183.62870  0.955783  0.004486  0.001882
#
#          dw_03     dw_04     dw_05     dw_06     dw_07  ...    lan_11  \
# 0     0.006891  0.021287  0.015615  0.035974  0.010995  ...  0.000420
# 1     0.000000  0.000000  0.000000  0.002633  0.005074  ...  0.000000
# 2     0.000000  0.000000  0.000000  0.018546  0.004769  ...  0.000631
# 3     0.000279  0.000799  0.197760  0.005227  0.065487  ...  0.000593
# 4     0.008975  0.047882  0.015398  0.007264  0.000000  ...  0.000234
# ...        ...       ...       ...       ...       ...  ...       ...
# 1097  0.001706  0.001052  0.001353  0.008017  0.009431  ...  0.000000
# 1098  0.000000  0.001936  0.000000  0.003351  0.232637  ...  0.008148
# 1099  0.000859  0.000669  0.003711  0.029519  0.013913  ...  0.000431
# 1100  0.000485  0.000000  0.449604  0.009256  0.101963  ...  0.000000
# 1101  0.000000  0.000583  0.010246  0.003845  0.005151  ...  0.001523
#
#         lan_12  lan_13    lan_14     pg_00     pg_01     pg_02     pg_03  \
# 0     0.011485     0.0  0.063705  0.979272  0.009926  0.003224  0.002697
# 1     0.000160     0.0  0.000000  0.998938  0.000296  0.000301  0.000305
# 2     0.006504     0.0  0.000171  0.955895  0.012170  0.000000  0.030012
# 3     0.008330     0.0  0.000000  0.293629  0.694779  0.003238  0.000628
# 4     0.016846     0.0  0.178598  0.110861  0.054114  0.006062  0.823495
# ...        ...     ...       ...       ...       ...       ...       ...
# 1097  0.006982     0.0  0.012813  0.904646  0.034943  0.002611  0.055046
# 1098  0.041159     0.0  0.000000  0.965275  0.012481  0.000823  0.000627
# 1099  0.006319     0.0  0.006846  0.993986  0.001846  0.000673  0.000468
# 1100  0.001208     0.0  0.099216  0.102274  0.832795  0.006965  0.054769
# 1101  0.007339     0.0  0.000647  0.583842  0.350293  0.002910  0.058837
#
#          pg_04    lgt_00
# 0     0.004882  0.521007
# 1     0.000160  0.693716
# 2     0.001923  0.933954
# 3     0.007726  0.921470
# 4     0.005470  0.996227
# ...        ...       ...
# 1097  0.002753  0.256395
# 1098  0.020794  0.989622
# 1099  0.003028  0.938536
# 1100  0.003197  0.965817
# 1101  0.004118  0.859614
#
# [1102 rows x 48 columns]

# %%
Training_data.drop(['ward'],inplace=True,axis=1)
Testing_data.drop(['ward'],inplace=True,axis=1)

#converting columns to float
Training_data[1:19] = Training_data[1:48].astype(float)
Testing_data[1:19] = Testing_data[1:48].astype(float)

# %%
Training.dtypes
# Out:
# total_households        float64
# total_individuals       float64
# target_pct_vunerable    float64
# dw_00                   float64
# dw_01                   float64
# dw_02                   float64
# dw_03                   float64
# dw_04                   float64
# dw_05                   float64
# dw_06                   float64
# dw_07                   float64
# dw_08                   float64
# dw_09                   float64
# dw_10                   float64
# dw_11                   float64
# dw_12                   float64
# dw_13                   float64
# psa_00                  float64
# psa_01                  float64
# psa_02                  float64
# psa_03                  float64
# psa_04                  float64
# stv_00                  float64
# stv_01                  float64
# car_00                  float64
# car_01                  float64
# lln_00                  float64
# lln_01                  float64
# lan_00                  float64
# lan_01                  float64
# lan_02                  float64
# lan_03                  float64
# lan_04                  float64
# lan_05                  float64
# lan_06                  float64
# lan_07                  float64
# lan_08                  float64
# lan_09                  float64
# lan_10                  float64
# lan_11                  float64
# lan_12                  float64
# lan_13                  float64
# lan_14                  float64
# pg_00                   float64
# pg_01                   float64
# pg_02                   float64
# pg_03                   float64
# pg_04                   float64
# lgt_00                  float64
# dtype: object

# %%
Training_data.shape
# Out:
# (3174, 49)

# %%
Testing_data.dtypes
# Out:
# total_households     float64
# total_individuals    float64
# dw_00                float64
# dw_01                float64
# dw_02                float64
# dw_03                float64
# dw_04                float64
# dw_05                float64
# dw_06                float64
# dw_07                float64
# dw_08                float64
# dw_09                float64
# dw_10                float64
# dw_11                float64
# dw_12                float64
# dw_13                float64
# psa_00               float64
# psa_01               float64
# psa_02               float64
# psa_03               float64
# psa_04               float64
# stv_00               float64
# stv_01               float64
# car_00               float64
# car_01               float64
# lln_00               float64
# lln_01               float64
# lan_00               float64
# lan_01               float64
# lan_02               float64
# lan_03               float64
# lan_04               float64
# lan_05               float64
# lan_06               float64
# lan_07               float64
# lan_08               float64
# lan_09               float64
# lan_10               float64
# lan_11               float64
# lan_12               float64
# lan_13               float64
# lan_14               float64
# pg_00                float64
# pg_01                float64
# pg_02                float64
# pg_03                float64
# pg_04                float64
# lgt_00               float64
# dtype: object

# %%
Testing_data

# %%
k = 0
z =40
Training_data = Training_data.drop(Training_data.loc[k:z].index, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-5a637ba65939> in <module>
#       2 z =40
#       3 #Training_data =
# ----> 4 Training_data.drop(Training_data.loc[k:z].index, inplace = True)
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
Training_data.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-2762ef13c6a8> in <module>
# ----> 1 Training_data.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
n = 0
m =1
Testing_data = Testing_data.drop(Testing_data.loc[n:m].index, inplace = True)

# %%
Testing_data.shape

# %%
# Checking the missing values

missing_df = Training_data.isnull().sum(axis=0).reset_index()
missing_df.columns = ['Column Name', 'Missing Values Count']
missing_df['Filling Factor (%)']=(Training_data.shape[0]-missing_df['Missing Values Count'])/Training_data.shape[0]*100
missing_df.sort_values('Filling Factor (%)').reset_index(drop = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-65f1a888dbd0> in <module>
#       1 # Checking the missing values
#       2
# ----> 3 missing_df = Training_data.isnull().sum(axis=0).reset_index()
#       4 missing_df.columns = ['Column Name', 'Missing Values Count']
#       5 missing_df['Filling Factor (%)']=(Training_data.shape[0]-missing_df['Missing Values Count'])/Training_data.shape[0]*100
#
# AttributeError: 'NoneType' object has no attribute 'isnull'

# %%
X= Training_data[['total_households', 'total_individuals','dw_00', 'dw_01', 'dw_02', 'dw_03','dw_04', 'dw_05', 'dw_06', 'dw_07', 'dw_08', 'dw_09','dw_10',
       'dw_11', 'dw_12','dw_13','psa_00', 'psa_01', 'psa_02','psa_03', 'psa_04', 'stv_00', 'stv_01', 'car_00',
       'car_01','lln_00', 'lln_01', 'lan_00', 'lan_01','lan_02', 'lan_03', 'lan_04','lan_05','lan_06','lan_07', 'lan_08',
       'lan_09', 'lan_10','lan_11', 'lan_12', 'lan_13', 'lan_14','pg_00', 'pg_01', 'pg_02', 'pg_03', 'pg_04', 'lgt_00']]
Y= Training_data.target_pct_vunerable
Y = Y.astype('float')
print(Y)
# Out:
# 0       1.739801
# 1       1.993381
# 2       0.038340
# 3       7.411006
# 4       8.223907
#           ...
# 3169    3.500868
# 3170    0.116460
# 3171    0.958828
# 3172    1.024934
# 3173    5.283125
# Name: target_pct_vunerable, Length: 3174, dtype: float64

# %%
#X_train, X_test, Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X,Y, test_size=0.345, random_state=20)

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

#picking one model
model = LinearRegression()
model.fit(X_train, Y_train)  #training process

#ask the model to predict the x test while hiding the y test from the model (unseen data)
#predictions = model.predict(X_test)
predictions = model.predict(Testing_data)

#in regression we always check the R squared and, absolute error squared
from sklearn.metrics import r2_score, mean_squared_error

print("R squared(%):", r2_score(Y_test, predictions))
print("mean squared error:", mean_squared_error(Y_test, predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-3d365ae79fe2> in <module>
#      17 from sklearn.metrics import r2_score, mean_squared_error
#      18
# ---> 19 print("R squared(%):", r2_score(Y_test, predictions))
#      20 print("mean squared error:", mean_squared_error(Y_test, predictions))
#
# ~\.conda\envs\TensorFlow\lib\site-packages\sklearn\metrics\_regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
#     575     """
#     576     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 577         y_true, y_pred, multioutput)
#     578     check_consistent_length(y_true, y_pred, sample_weight)
#     579
#
# ~\.conda\envs\TensorFlow\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      82
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      86     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# ~\.conda\envs\TensorFlow\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     210     if len(uniques) > 1:
#     211         raise ValueError("Found input variables with inconsistent numbers of"
# --> 212                          " samples: %r" % [int(l) for l in lengths])
#     213
#     214
#
# ValueError: Found input variables with inconsistent numbers of samples: [1096, 1102]

# %%
SampleSubmission.head()

# %%
sampleSubmission = sampleSubmission.drop(['target_pct_vunerable'], axis=1)

# %%
SampleSubmission['target_pct_vunerable'] = test_pred

# %%
SampleSubmission.head()

# %%
SampleSubmission.to_csv('SampleSubmission.csv', index=False)
